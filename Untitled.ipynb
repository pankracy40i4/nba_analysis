# %%
import pymc3 as pm
import pandas as pd
import numpy as np

# %% [markdown]
# # Load data

# %%
df = pd.read_csv('teams-MITPM250039-553.csv')

# %%
df.describe()
# Out:
#          Unnamed: 0           AST       AST_PCT     AST_RATIO       AST_TOV  \
# count  10860.000000  10860.000000  10860.000000  10860.000000  10860.000000
# mean     180.503683     22.260773      0.581685     16.904457      1.691812
# std      104.511206      5.070381      0.102979      3.244092      0.702207
# min        0.000000      6.000000      0.200000      5.600000      0.320000
# 25%       90.000000     19.000000      0.513000     14.700000      1.210000
# 50%      180.500000     22.000000      0.583000     16.900000      1.560000
# 75%      271.000000     26.000000      0.651000     19.000000      2.000000
# max      366.000000     47.000000      0.933000     30.100000     10.000000
#
#                CFGA          CFGM       CFG_PCT    DEF_RATING          DFGA  \
# count  10860.000000  10860.000000  10860.000000  10860.000000  10860.000000
# mean      44.748435     20.915193      0.468556    104.463582     29.808471
# ...
